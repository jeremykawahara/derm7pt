# %%
# Python version.
import sys
sys.version
# Out:
# '3.5.2 (default, Jun 28 2016, 09:44:31) \n[GCC 5.3.1 20160413]'

# %%
import numpy as np
np.__version__
# Out:
# '1.14.1'

# %%
import matplotlib
matplotlib.__version__
# Out:
# '2.1.0'

# %%
import sklearn
sklearn.__version__
# Out:
# '0.18.2'

# %%
import pandas
pandas.__version__
# Out:
# '0.18.1'

# %%
import keras
keras.__version__
# Out:
# Using TensorFlow backend.
# '2.1.4'

# %%
import PIL
PIL.__version__
# Out:
# '5.1.0'
