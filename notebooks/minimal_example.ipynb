# %%
import sys, os
import pandas as pd
sys.path.insert(0, os.path.abspath(os.path.join(os.getcwd(), '..'))) # To import derm7pt
from derm7pt.dataset import Derm7PtDatasetGroupInfrequent

# Change this line to your data directory.
dir_release = '/local-scratch/jer/data/argenziano/release_v0'

# Dataset after grouping infrequent labels.
derm_data = Derm7PtDatasetGroupInfrequent(
    dir_images=os.path.join(dir_release, 'images'), 
    metadata_df=pd.read_csv(os.path.join(dir_release, 'meta/meta.csv')), 
    train_indexes=list(pd.read_csv(os.path.join(dir_release, 'meta/train_indexes.csv'))['indexes']), 
    valid_indexes=list(pd.read_csv(os.path.join(dir_release, 'meta/valid_indexes.csv'))['indexes']), 
    test_indexes=list(pd.read_csv(os.path.join(dir_release, 'meta/test_indexes.csv'))['indexes']))

# Outputs to screen the preprocessed dataset in a Pandas format.
derm_data.df
# Out:
# Using TensorFlow backend.
#       case_num             diagnosis  seven_point_score pigment_network  \
# 0            1  basal cell carcinoma                  0          absent
# 1            2  basal cell carcinoma                  1          absent
# 2            3  basal cell carcinoma                  1          absent
# 3            4  basal cell carcinoma                  4          absent
# 4            5  basal cell carcinoma                  1          absent
# 5            6  basal cell carcinoma                  1          absent
# 6            7  basal cell carcinoma                  0          absent
# 7            8  basal cell carcinoma                  4          absent
# 8            9  basal cell carcinoma                  0          absent
# 9           10  basal cell carcinoma                  2          absent
# 10          11  basal cell carcinoma                  3          absent
# 11          12  basal cell carcinoma                  2          absent
# 12          13  basal cell carcinoma                  1          absent
# 13          14  basal cell carcinoma                  2          absent
# 14          15  basal cell carcinoma                  2          absent
# 15          16  basal cell carcinoma                  0          absent
# 16          17  basal cell carcinoma                  3          absent
# 17          18  basal cell carcinoma                  4          absent
# 18          19  basal cell carcinoma                  5         typical
# 19          20  basal cell carcinoma                  3          absent
# 20          21  basal cell carcinoma                  1          absent
# 21          22  basal cell carcinoma                  3          absent
# 22          23  basal cell carcinoma                  3          absent
# 23          24  basal cell carcinoma                  0          absent
# 24          25  basal cell carcinoma                  1          absent
# 25          26  basal cell carcinoma                  2          absent
# 26          27  basal cell carcinoma                  0          absent
# 27          28  basal cell carcinoma                  0          absent
# 28          29  basal cell carcinoma                  2          absent
# 29          30  basal cell carcinoma                  0          absent
# ...        ...                   ...                ...             ...
# 981        982       vascular lesion                  0          absent
# 982        983       vascular lesion                  0          absent
# 983        984       vascular lesion                  0          absent
# 984        985       vascular lesion                  1          absent
# 985        986       vascular lesion                  1          absent
# 986        987       vascular lesion                  0          absent
# 987        988       vascular lesion                  0          absent
# 988        989       vascular lesion                  0          absent
# 989        990       vascular lesion                  0          absent
# 990        991       vascular lesion                  0          absent
# 991        992       vascular lesion                  0          absent
# 992        993       vascular lesion                  0          absent
# 993        994       vascular lesion                  1          absent
# 994        995       vascular lesion                  0          absent
# 995        996       vascular lesion                  0          absent
# 996        997       vascular lesion                  0         typical
# 997        998       vascular lesion                  0          absent
# 998        999       vascular lesion                  0          absent
# 999       1000       vascular lesion                  0          absent
# 1000      1001       vascular lesion                  0          absent
# 1001      1002       vascular lesion                  0          absent
# 1002      1003       vascular lesion                  0          absent
# 1003      1004       vascular lesion                  0          absent
# 1004      1005       vascular lesion                  0          absent
# 1005      1006       vascular lesion                  0          absent
# 1006      1007       vascular lesion                  0          absent
# 1007      1008       vascular lesion                  0          absent
# 1008      1009       vascular lesion                  0          absent
# 1009      1010       vascular lesion                  0          absent
# 1010      1011              melanoma                  2          absent
#
#         streaks         pigmentation regression_structures dots_and_globules  \
# 0        absent               absent                absent            absent
# 1        absent               absent                absent         irregular
# 2        absent               absent                absent         irregular
# 3        absent               absent            blue areas         irregular
# 4        absent    diffuse irregular                absent            absent
# 5        absent    diffuse irregular                absent            absent
# 6        absent               absent                absent            absent
# 7        absent    diffuse irregular                absent         irregular
# 8        absent               absent                absent            absent
# 9        absent    diffuse irregular                absent         irregular
# 10       absent               absent                absent         irregular
# 11       absent               absent          combinations         irregular
# 12       absent    diffuse irregular                absent            absent
# 13       absent    diffuse irregular           white areas            absent
# 14       absent    diffuse irregular            blue areas            absent
# 15       absent               absent                absent            absent
# 16    irregular               absent                absent            absent
# 17       absent  localized irregular                absent         irregular
# 18    irregular  localized irregular                absent         irregular
# 19       absent               absent                absent         irregular
# 20       absent               absent                absent         irregular
# 21       absent               absent                absent         irregular
# 22       absent               absent                absent         irregular
# 23       absent               absent                absent            absent
# 24       absent    diffuse irregular                absent            absent
# 25       absent    diffuse irregular                absent         irregular
# 26       absent               absent                absent            absent
# 27       absent               absent                absent            absent
# 28       absent    diffuse irregular                absent         irregular
# 29       absent               absent                absent            absent
# ...         ...                  ...                   ...               ...
# 981      absent      diffuse regular                absent            absent
# 982      absent      diffuse regular                absent            absent
# 983      absent      diffuse regular                absent            absent
# 984      absent               absent                absent         irregular
# 985      absent               absent                absent         irregular
# 986      absent      diffuse regular                absent            absent
# 987      absent               absent                absent            absent
# 988      absent               absent                absent            absent
# 989      absent               absent                absent            absent
# 990      absent               absent                absent            absent
# 991      absent               absent                absent            absent
# 992      absent               absent                absent            absent
# 993      absent    diffuse irregular                absent            absent
# 994      absent      diffuse regular                absent            absent
# 995      absent      diffuse regular                absent            absent
# 996      absent               absent                absent            absent
# 997      absent               absent                absent            absent
# 998      absent               absent                absent            absent
# 999      absent      diffuse regular                absent            absent
# 1000     absent      diffuse regular                absent           regular
# 1001     absent               absent                absent            absent
# 1002     absent               absent                absent            absent
# 1003     absent               absent                absent            absent
# 1004     absent               absent                absent            absent
# 1005     absent      diffuse regular                absent           regular
# 1006     absent               absent                absent            absent
# 1007     absent               absent                absent            absent
# 1008     absent               absent                absent            absent
# 1009     absent      diffuse regular                absent            absent
# 1010     absent    diffuse irregular           white areas            absent
#
#      blue_whitish_veil vascular_structures              ...                \
# 0               absent          arborizing              ...
# 1               absent              absent              ...
# 2               absent          arborizing              ...
# 3              present   within regression              ...
# 4               absent              absent              ...
# 5               absent              absent              ...
# 6               absent          arborizing              ...
# 7              present              absent              ...
# 8               absent          arborizing              ...
# 9               absent          arborizing              ...
# 10             present          arborizing              ...
# 11              absent          arborizing              ...
# 12              absent          arborizing              ...
# 13              absent              absent              ...
# 14              absent              absent              ...
# 15              absent              absent              ...
# 16             present             hairpin              ...
# 17              absent              dotted              ...
# 18             present              absent              ...
# 19             present          arborizing              ...
# 20              absent              absent              ...
# 21             present              absent              ...
# 22             present          arborizing              ...
# 23              absent          arborizing              ...
# 24              absent          arborizing              ...
# 25              absent          arborizing              ...
# 26              absent          arborizing              ...
# 27              absent          arborizing              ...
# 28              absent          arborizing              ...
# 29              absent             hairpin              ...
# ...                ...                 ...              ...
# 981             absent              absent              ...
# 982             absent              absent              ...
# 983             absent              absent              ...
# 984             absent              absent              ...
# 985             absent              absent              ...
# 986             absent              absent              ...
# 987             absent              absent              ...
# 988             absent              absent              ...
# 989             absent              absent              ...
# 990             absent              absent              ...
# 991             absent              absent              ...
# 992             absent              absent              ...
# 993             absent              absent              ...
# 994             absent              absent              ...
# 995             absent              absent              ...
# 996             absent              absent              ...
# 997             absent              absent              ...
# 998             absent              absent              ...
# 999             absent              absent              ...
# 1000            absent              absent              ...
# 1001            absent              absent              ...
# 1002            absent              absent              ...
# 1003            absent              absent              ...
# 1004            absent              absent              ...
# 1005            absent              absent              ...
# 1006            absent              absent              ...
# 1007            absent              absent              ...
# 1008            absent              absent              ...
# 1009            absent              absent              ...
# 1010            absent              absent              ...
#
#        case_id notes diagnosis_numeric pigment_network_numeric  \
# 0          NaN   NaN                 0                       0
# 1          NaN   NaN                 0                       0
# 2          NaN   NaN                 0                       0
# 3          NaN   NaN                 0                       0
# 4          NaN   NaN                 0                       0
# 5          NaN   NaN                 0                       0
# 6          NaN   NaN                 0                       0
# 7          NaN   NaN                 0                       0
# 8          NaN   NaN                 0                       0
# 9          NaN   NaN                 0                       0
# 10         NaN   NaN                 0                       0
# 11         NaN   NaN                 0                       0
# 12         NaN   NaN                 0                       0
# 13         NaN   NaN                 0                       0
# 14         NaN   NaN                 0                       0
# 15         NaN   NaN                 0                       0
# 16         NaN   NaN                 0                       0
# 17         NaN   NaN                 0                       0
# 18         NaN   NaN                 0                       1
# 19         NaN   NaN                 0                       0
# 20         NaN   NaN                 0                       0
# 21         NaN   NaN                 0                       0
# 22         NaN   NaN                 0                       0
# 23         NaN   NaN                 0                       0
# 24         NaN   NaN                 0                       0
# 25         NaN   NaN                 0                       0
# 26         NaN   NaN                 0                       0
# 27         NaN   NaN                 0                       0
# 28         NaN   NaN                 0                       0
# 29         NaN   NaN                 0                       0
# ...        ...   ...               ...                     ...
# 981        NaN   NaN                 3                       0
# 982        NaN   NaN                 3                       0
# 983        NaN   NaN                 3                       0
# 984        NaN   NaN                 3                       0
# 985        NaN   NaN                 3                       0
# 986        NaN   NaN                 3                       0
# 987        NaN   NaN                 3                       0
# 988        NaN   NaN                 3                       0
# 989        NaN   NaN                 3                       0
# 990        NaN   NaN                 3                       0
# 991        NaN   NaN                 3                       0
# 992        NaN   NaN                 3                       0
# 993   1e797877   NaN                 3                       0
# 994        NaN   NaN                 3                       0
# 995        NaN   NaN                 3                       0
# 996        NaN   NaN                 3                       1
# 997        NaN   NaN                 3                       0
# 998        NaN   NaN                 3                       0
# 999        NaN   NaN                 3                       0
# 1000       NaN   NaN                 3                       0
# 1001       NaN   NaN                 3                       0
# 1002       NaN   NaN                 3                       0
# 1003       NaN   NaN                 3                       0
# 1004       NaN   NaN                 3                       0
# 1005       NaN   NaN                 3                       0
# 1006       NaN   NaN                 3                       0
# 1007       NaN   NaN                 3                       0
# 1008       NaN   NaN                 3                       0
# 1009       NaN   NaN                 3                       0
# 1010       NaN   NaN                 2                       0
#
#      blue_whitish_veil_numeric vascular_structures_numeric  \
# 0                            0                           1
# 1                            0                           0
# 2                            0                           1
# 3                            1                           1
# 4                            0                           0
# 5                            0                           0
# 6                            0                           1
# 7                            1                           0
# 8                            0                           1
# 9                            0                           1
# 10                           1                           1
# 11                           0                           1
# 12                           0                           1
# 13                           0                           0
# 14                           0                           0
# 15                           0                           0
